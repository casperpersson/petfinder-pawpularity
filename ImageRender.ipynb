# %%
! pip install pillow
! pip install opencv-python
# Out:
# Requirement already satisfied: pillow in c:\users\grubb\appdata\local\programs\python\python311\lib\site-packages (10.2.0)
# Requirement already satisfied: opencv-python in c:\users\grubb\appdata\local\programs\python\python311\lib\site-packages (4.11.0.86)
# Requirement already satisfied: numpy>=1.21.2 in c:\users\grubb\appdata\local\programs\python\python311\lib\site-packages (from opencv-python) (1.26.4)

# %%
import os
from PIL import Image
# Load an image
img = Image.open('Paris.webp')
# Display the image
img.show()

# %%
import cv2
import numpy as np
import matplotlib.pyplot as plt

plt.imshow(np.array(img))


# Convert the image to grayscale
img_gray = img.convert('L')
# Display the image 
img_gray.show()

plt.imshow(np.array(img_gray), cmap='gray')

# Convert the image to a numpy array
img_array = np.array(img)
# Display the shape of the image
print('Image shape:', img_array.shape)
# Display the image
plt.imshow(img_array)
# Out:
# Image shape: (2560, 3840, 3)

# %%
# Extract the RGB channels
r, g, b = cv2.split(img_array)

# Red channel
plt.figure(figsize=(10, 3))
plt.imshow(r, cmap='Reds')
plt.title('Red Channel')
plt.axis('off')

# Green channel
plt.figure(figsize=(10, 3))
plt.imshow(g, cmap='Greens')
plt.title('Green Channel')
plt.axis('off')

# Blue channel
plt.figure(figsize=(10, 3))
plt.imshow(b, cmap='Blues')
plt.title('Blue Channel')
plt.axis('off')

# Grayscale image
plt.figure(figsize=(10, 3))
plt.imshow(img_gray, cmap='gray')
plt.title('Grayscale Image')
plt.axis('off')

plt.show()
